# %%
# Analytical Tools
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# General Utilities
import math
import json
import pprint
import itertools
import importlib

# Some settings
from IPython.display import Markdown, display
log = pprint.pprint
space = lambda: print()
printmd = lambda text: display(Markdown(text))
# %matplotlib inline

def set_pandas_display_options() -> None:
    """Set pandas display options."""
    display = pd.options.display

    display.max_columns = 1000
    display.max_rows = 1000
    display.max_colwidth = 199
    display.width = 1000
    # display.precision = 2  # set as needed

set_pandas_display_options()

# %%
non_insight = ['What day follows the day before yesterday if two days from now will be Sunday?',
'Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?',
'Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; the Social Security office is closed weekends; the dentist has office hours only on Tuesday, Friday, and Saturday; the art gallery is closed Tuesday, Thursday, and weekends. On what single day can I do everything I have planned?',
'A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now facing?',
'The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not in fridge. My fourth letter is in treat but not in absent. What is the word that this verse described?'];
 
anagram = ['Solve this anagram: NCRBOA', 
						'Solve this anagram: AYKAWLJ', 
						'Solve this anagram: EVANG',
						'Solve this anagram: MARNOD',
						'Solve this anagram: AALRYS']

# %%
with open('pilot4.json') as json_file:
    data = json.load(json_file)

# %%
questions_non_insight = []
answers_non_insight = [] #whether people typed done or skip
solutions_non_insight = []
confidence_non_insight = []
difficulty_non_insight = []
aha_non_insight = []
rts_non_insight = []
close_non_insight = []

questions_insight = []
answers_insight = []
solutions_insight = []
confidence_insight = []
difficulty_insight = []
aha_insight = []
rts_insight = []
close_insight = []

questions_anagram = []
solutions_anagram = []
answers_anagram = []
confidence_anagram = []
difficulty_anagram = []
aha_anagram = []
rts_anagram = []
close_anagram = []

for i in range(len(data)): #go thru the subjects
    if len(data[i]['data']) > 3: #only look at subjects that finished the task (and not just started without finishing)
        if 1 == 1: #'DONE' in data[i]['data'][3]['responses']: #passed attention/quiz check (for now we are considering all subjects)
            
            k = 5
            
            for j in range(2):
                question = data[i]['data'][0]['problems_seen'][j] #store the question seen by the participant
                answers = []
                rt = 0     
                counter = 0
                bad_subject = 0
                close = []
                
                while True:
                    answer = data[i]['data'][k]['responses']
                    if(len(answer) > 9): #Did the subject type a response in the box?
                        counter = counter + 1

                    answers.append(answer)
                    k = k+1
                    close.append(int(data[i]['data'][k]['response']))
                    if 'done' not in answer.lower() and 'skip' not in answer.lower():
                        rt = rt+10
                        k = k+1
                    else:
                        rt = rt + data[i]['data'][k]['rt']/1000
                        k = k+1
                        if counter > 3: #subject has typed a response in the box more than 6 times for the problems-- not reading instruction!
                            bad_subject = 1
                        break
                
                solution = data[i]['data'][k]['responses'] #store people's solution here
                k = k+1
                response = data[i]['data'][k]['responses'] #store people's responses to the judgment questions here
                k = k+2 #move to the next question
                
                if bad_subject == 0 and question in non_insight:   
                    questions_non_insight.append(question)
                    answers_non_insight.append(answers)
                    solutions_non_insight.append(solution)
                    rts_non_insight.append(rt)
                    confidence_non_insight.append(int(response[6])+1)
                    difficulty_non_insight.append(int(response[13])+1)
                    aha_non_insight.append(int(response[20])+1)
                    close_non_insight.append(close)

                elif bad_subject == 0 and question in anagram:
                    questions_anagram.append(question)
                    answers_anagram.append(answers)
                    solutions_anagram.append(solution)
                    rts_anagram.append(rt)
                    confidence_anagram.append(int(response[6])+1)
                    difficulty_anagram.append(int(response[13])+1)
                    aha_anagram.append(int(response[20])+1)
                    close_anagram.append(close)
                else:
                    print(bad_subject, question)
        else:
            print(data[i]['data'][3]['responses'])
            print('bad subject!')
# Out:
# 1 Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?
# 1 Solve this anagram: EVANG
# 1 Solve this anagram: MARNOD
# 1 Solve this anagram: MARNOD
# 1 Solve this anagram: AALRYS
# 1 Solve this anagram: MARNOD

# %% [markdown]
# Convert data into df

# %%
d = {'questions':questions_non_insight,
     'answers':answers_non_insight, 
     'solutions': solutions_non_insight,
     'rts': rts_non_insight,
     'confidence': confidence_non_insight, 
     'difficulty': difficulty_non_insight, 
     'aha': aha_non_insight,
     'close': close_non_insight}

d2 = {'questions':questions_anagram,
     'answers':answers_anagram, 
      'solutions': solutions_anagram,
     'rts': rts_anagram,
     'confidence': confidence_anagram, 
     'difficulty': difficulty_anagram, 
     'aha': aha_anagram,
     'close': close_anagram}

df_non_insight = pd.DataFrame(d)
df_anagram = pd.DataFrame(d2)

#correct answers to the problems
solutions1 = 'thursday|41|friday|north|south|west|right|left|pear'
solutions2 = 'carbon|jaywalk|vegan|random|salary'

#analyze only those responses for which people's answer is correct, and remove subjects who solve the task before 7 seconds (that's it; easy exclusion criteria)
df_non_insight_filtered = df_non_insight.loc[(df_non_insight['solutions'].str.contains(solutions1, case = False)==True)
                                             & (df_non_insight['close'].str[0] != 100) 
                                             & (df_non_insight['close'].str.len() > 1)]

df_anagram_filtered = df_anagram.loc[(df_anagram['solutions'].str.contains(solutions2, case = False)==True) 
                                     & (df_anagram['close'].str[0] != 100) 
                                     & (df_anagram['close'].str.len() > 1)]

print(len(df_non_insight.index), len(df_non_insight_filtered.index))
print(len(df_anagram.index), len(df_anagram_filtered.index))
# Out:
# 99 58
# 95 37

# %%
df_non_insight_filtered
# Out:
#                                                                                                                                                                                                  questions                                                                                                                                                                                                 answers             solutions       rts  confidence  difficulty  aha                                                                                           close
# 0   A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                                                   [{"Q0":""}, {"Q0":""}, {"Q0":"done"}]         {"Q0":"west"}   22.8621           6           4    4                                                                                    [41, 78, 94]
# 1   The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                            [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"pear"}   72.8917           6           3    2                                                                       [0, 3, 0, 2, 0, 2, 0, 99]
# 4   Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                 [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"Friday"}   82.4096           6           2    2                                                            [6, 14, 22, 46, 55, 83, 90, 93, 100]
# 5   Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Done"}]      {"Q0":"Friday "}   62.3180           6           3    5                                                                         [1, 0, 0, 0, 7, 0, 100]
# 6                         Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                            [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]           {"Q0":"41"}   72.5610           6           5    2                                                               [22, 27, 46, 59, 70, 68, 97, 100]
# 9                         Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]           {"Q0":"41"}   52.4954           7           5    4                                                                         [0, 8, 3, 76, 100, 100]
# 10  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"do"}, {"Q0":"DONE"}]        {"Q0":"south"}   43.3005           7           1    2                                                                          [28, 33, 56, 100, 100]
# 11                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                            [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]           {"Q0":"41"}   73.6422           7           1    1                                                                [21, 27, 36, 38, 41, 38, 33, 83]
# 12  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"Friday"}   53.0148           7           2    1                                                                           [0, 0, 0, 1, 45, 100]
# 13                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"FRIDAY"}   42.4567           4           4    4                                                                             [7, 15, 45, 97, 90]
# 15                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]           {"Q0":"41"}   41.8737           5           3    3                                                                           [21, 18, 70, 85, 100]
# 18  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                      [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"Friday"}   92.3321           6           5    1                                                        [0, 4, 18, 52, 54, 54, 79, 83, 100, 100]
# 19                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                               [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"41"}, {"Q0":"DONE"}]           {"Q0":"41"}   82.7670           6           2    5                                                               [0, 10, 13, 8, 0, 3, 41, 72, 100]
# 20                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                               [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"41"}, {"Q0":"DONE"}]           {"Q0":"41"}   82.4969           7           5    5                                                         [52, 53, 36, 53, 71, 64, 100, 100, 100]
# 22                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]          {"Q0":"$41"}   33.3534           5           3    2                                                                                 [4, 16, 81, 97]
# 23  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"...         {"Q0":"Pear"}  284.3153           5           6    6  [3, 5, 9, 4, 9, 10, 4, 7, 3, 3, 11, 5, 3, 2, 3, 1, 5, 3, 3, 3, 2, 0, 10, 8, 6, 51, 57, 93, 81]
# 27                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                               [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Thursday"}, {"Q0":"Done"}]     {"Q0":"Thursday"}   63.2030           4           7    1                                                                    [0, 47, 0, 36, 32, 100, 100]
# 28  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                                    [{"Q0":""}, {"Q0":""}, {"Q0":"LEFT"}, {"Q0":"DONE"}]         {"Q0":"Left"}   32.2546           6           5    3                                                                                 [0, 74, 97, 97]
# 29                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                          [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Thursday"}  133.1652           6           6    4                                            [0, 12, 7, 10, 5, 9, 17, 15, 11, 26, 51, 61, 86, 93]
# 31  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                     [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"friday"}, {"Q0":"friday"}, {"Q0":""}, {"Q0":"done"}]       {"Q0":"friday"}   83.4302           5           6    3                                                              [4, 9, 10, 19, 45, 82, 70, 57, 70]
# 32  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                 [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"Friday"}   84.9573           7           2    3                                                              [0, 0, 0, 6, 19, 14, 52, 100, 100]
# 33  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"Pear"}   42.7792           3           4    3                                                                               [2, 0, 0, 73, 85]
# 34  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                                                         [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"pear"}, {"Q0":"DONE"}]         {"Q0":"pear"}   43.8305           6           2    2                                                                              [9, 8, 7, 100, 98]
# 35  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                [{"Q0":""}, {"Q0":""}, {"Q0":"Wes"}, {"Q0":"West"}, {"Q0":""}, {"Q0":""}, {"Q0":"Skip"}]         {"Q0":"West"}   63.3141           4           7    2                                                                    [30, 51, 100, 100, 52, 2, 1]
# 38  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DO"}, {"Q0":"DONE"}]        {"Q0":"North"}   41.8217           5           4    2                                                                            [18, 11, 51, 95, 94]
# 39  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]  {"Q0":"left (west)"}   33.1008           4           2    4                                                                                [0, 53, 100, 97]
# 40  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]         {"Q0":"pear"}   51.9463           6           4    3                                                                        [10, 27, 38, 46, 47, 89]
# 42  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]       {"Q0":"Friday"}   53.5223           6           2    4                                                                           [0, 0, 0, 34, 75, 92]
# 43  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]        {"Q0":"South"}   52.7068           5           4    3                                                                           [2, 2, 0, 44, 93, 91]
# 44  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"friday"}   33.0861           7           4    5                                                                                 [0, 0, 51, 100]
# 45                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Done"}]     {"Q0":"Thursday"}   62.8490           3           2    1                                                                      [0, 0, 0, 0, 53, 100, 100]
# 47                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                               [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Thursday"}, {"Q0":"done"}]     {"Q0":"Thursday"}   62.8678           4           5    2                                                                    [24, 36, 51, 64, 72, 87, 97]
# 48                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DO"}, {"Q0":"DONE"}]     {"Q0":"Thursday"}   43.7199           7           3    1                                                                            [12, 6, 16, 97, 100]
# 49  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]        {"Q0":"NORTH"}   55.1000           4           4    4                                                                           [0, 0, 0, 49, 77, 85]
# 50                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Thursday"}   38.7898           5           1    1                                                                                 [0, 67, 98, 97]
# 51                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]           {"Q0":"41"}   44.4187           5           5    1                                                                               [0, 0, 0, 0, 100]
# 52  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"pear"}  103.1800           5           4    4                                                          [0, 0, 0, 1, 0, 2, 16, 14, 47, 87, 88]
# 53  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"WEST"}   55.1663           6           3    5                                                                        [21, 23, 21, 24, 91, 17]
# 54  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"Friday"}   63.5759           6           4    5                                                                       [0, 0, 0, 0, 0, 100, 100]
# 56  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"friday"}   42.7900           6           2    4                                                                            [15, 51, 64, 90, 98]
# 57  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]        {"Q0":"South"}   53.0889           5           7    1                                                                          [3, 2, 0, 36, 73, 100]
# 60                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                           [{"Q0":""}, {"Q0":"Thursday"}, {"Q0":"DONE"}]     {"Q0":"Thursday"}   21.6030           5           5    5                                                                                    [72, 61, 74]
# 61  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                 [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Done"}]        {"Q0":"South"}   83.2751           6           5    2                                                             [21, 35, 23, 7, 30, 57, 67, 83, 91]
# 63  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]        {"Q0":"north"}   32.4736           5           3    2                                                                                [0, 27, 54, 100]
# 66                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Done"}]       {"Q0":"Friday"}   33.2767           5           4    4                                                                                 [2, 11, 53, 98]
# 67                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                                              [{"Q0":""}, {"Q0":"Done"}]     {"Q0":"Thursday"}   13.3510           7           2    1                                                                                       [54, 100]
# 68  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"Friday"}  102.8907           6           3    4                                                          [2, 2, 2, 4, 6, 3, 5, 37, 31, 84, 100]
# 71  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Done"}]        {"Q0":"North"}   42.3268           5           3    1                                                                             [3, 6, 27, 91, 100]
# 74  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"Friday"}   35.1329           5           4    2                                                                                  [0, 0, 54, 95]
# 76  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]        {"Q0":"South"}   43.2543           6           5    1                                                                            [2, 39, 18, 68, 100]
# 80  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                            [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"friday"}, {"Q0":"done"}]       {"Q0":"friday"}   53.3752           3           5    1                                                                        [16, 25, 53, 90, 87, 87]
# 81                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":"D"}, {"Q0":"done"}]     {"Q0":"Thursday"}   34.9529           6           3    2                                                                                 [20, 5, 99, 99]
# 85                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]           {"Q0":"41"}   52.7355           5           4    3                                                                           [2, 7, 6, 38, 76, 57]
# 87  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"NORTH"}, {"Q0":"DONE"}]        {"Q0":"NORTH"}   72.8190           4           5    3                                                                  [0, 0, 0, 51, 83, 75, 100, 86]
# 89                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                      [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]           {"Q0":"41"}   94.1210           5           4    3                                                              [0, 1, 10, 7, 7, 8, 8, 16, 56, 90]
# 90                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                               [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"FR"}, {"Q0":"DONE"}]       {"Q0":"Friday"}   83.1196           4           4    2                                                            [30, 31, 36, 40, 66, 64, 55, 65, 77]
# 95  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]         {"Q0":"pear"}   42.0560           7           6    5                                                                          [16, 23, 51, 100, 100]
# 98                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"41"}, {"Q0":"4"}, {"Q0":"DONE"}]           {"Q0":"41"}  122.7040           7           3    6                                           [10, 15, 11, 13, 22, 13, 8, 9, 20, 75, 100, 100, 100]

# %% [markdown]
# For the filtered data, get people's prediction error (when they said greater than 95 and last point before that)

# %%
tpe_non_insight = []
ahas_non_insight = []
increment_non_insight = []

for i in range(len(df_non_insight_filtered.index)):
    a = df_non_insight_filtered['close'].iloc[i]
    aha = df_non_insight_filtered['aha'].iloc[i]
    increments = []
    for j in range(len(a)):
            
            if j == 0:
                increments.append(a[j] - 0)
            
            elif (a[j] < 95):    
                increments.append(a[j] - a[j-1])
            
            elif(a[j] > 95): #subject gave greater than 90 confidence!
                tpe_non_insight.append(a[j] - a[j-1])
                ahas_non_insight.append(aha)
                increment_non_insight.append(increments)
                break

tpe_anagram = []
ahas_anagram = []
increment_anagram = []

for i in range(len(df_anagram_filtered.index)):
    a = df_anagram_filtered['close'].iloc[i]
    aha = df_anagram_filtered['aha'].iloc[i]
    increments = []
    for j in range(len(a)):
        
            if j == 0:
                increments.append(a[j] - a[j])
            
            elif (a[j] < 95):    
                increments.append(a[j] - a[j-1])
        
            if(a[j] > 95): #subject gave greater than 90 confidence!
                tpe_anagram.append(a[j] - a[j-1])
                ahas_anagram.append(aha)
                increment_anagram.append(increments)
                break
            
print(np.mean(tpe_non_insight))
print(np.mean(ahas_non_insight))

print(np.mean(tpe_anagram))
print(np.mean(ahas_anagram))

#print(np.corrcoef(ahas_non_insight+ahas_anagram, tpe_non_insight+tpe_anagram))
print(np.mean(sum(increment_non_insight, [])))
print(np.mean(sum(increment_anagram, [])))
# Out:
# 44.473684210526315
# 2.710526315789474
# 58.114285714285714
# 5.285714285714286
# 11.90857142857143
# 4.89

# %% [markdown]
# To do -- [check ratio (increment per probe), difference between last rating and 100, and average plot of warmth rating for each problem]

# %% [markdown]
# Create separate dfs for each non insight question

# %%
df1 = df_non_insight_filtered.loc[(df_non_insight['questions'].str.contains("yesterday", case=False))]
df2 = df_non_insight_filtered.loc[(df_non_insight['questions'].str.contains("giraffe", case=False))]
df3 = df_non_insight_filtered.loc[(df_non_insight['questions'].str.contains("soldiers", case=False))]
df4 = df_non_insight_filtered.loc[(df_non_insight['questions'].str.contains("security", case=False))]
df5 = df_non_insight_filtered.loc[(df_non_insight['questions'].str.contains("cheaper", case=False))]

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd

fig = plt.figure(figsize=(13, 7))
gs = gridspec.GridSpec(2, 6)

for i in range(0, 5):
    if i < 3:
        ax = plt.subplot(gs[0, 2 * i:2 * i + 2])
    else:
        ax = plt.subplot(gs[1, 2 * i - 11:2 * i + 2 - 11])
    
    if i == 0:
        max_len = max(df1['close'].str.len())
        for j, row in df1.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends in the plot
            plt.plot(x2, row['close'], '-o')
        plt.title(df1['questions'].iloc[0][0:20]+'...'+'\n aha ='+str(round(df1['aha'].mean(),1))
                 +' diff ='+str(round(df1['difficulty'].mean(),1))+'\n rt ='+str(round(df1['rts'].mean(),1))
                 +' conf ='+str(round(df1['confidence'].mean(),1)))
    elif i == 1:
        max_len = max(df2['close'].str.len())
        for j, row in df2.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends
            plt.plot(x2, row['close'], '-o')
        plt.title(df2['questions'].iloc[0][0:20]+'...'+'\n aha ='+str(round(df2['aha'].mean(),1))
                 +' diff ='+str(round(df2['difficulty'].mean(),1))+'\n rt ='+str(round(df2['rts'].mean(),1))
                 +' conf ='+str(round(df2['confidence'].mean(),1)))
    elif i == 2:
        max_len = max(df3['close'].str.len())
        for j, row in df3.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends
            plt.plot(x2, row['close'], '-o')
        plt.title(df3['questions'].iloc[0][0:20]+'...'+'\n aha ='+str(round(df3['aha'].mean(),1))
                 +' diff ='+str(round(df3['difficulty'].mean(),1))+'\n rt ='+str(round(df3['rts'].mean(),1))
                 +' conf ='+str(round(df3['confidence'].mean(),1)))
    elif i == 3:
        max_len = max(df4['close'].str.len())
        for j, row in df4.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends
            plt.plot(x2, row['close'], '-o')
        plt.title(df4['questions'].iloc[0][0:15]+'...'+'\n aha ='+str(round(df4['aha'].mean(),1))
                 +' diff ='+str(round(df4['difficulty'].mean(),1))+'\n rt ='+str(round(df4['rts'].mean(),1))
                 +' conf ='+str(round(df4['confidence'].mean(),1)))
    elif i == 4:
        max_len = max(df5['close'].str.len())
        for j, row in df5.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends
            plt.plot(x2, row['close'], '-o')
        plt.title(df5['questions'].iloc[0][0:15]+'...'+'\n aha ='+str(round(df5['aha'].mean(),1))
                 +' diff ='+str(round(df5['difficulty'].mean(),1))+'\n rt ='+str(round(df5['rts'].mean(),1))
                 +' conf ='+str(round(df5['confidence'].mean(),1)))
            
plt.tight_layout()
plt.show()

# %%
df6 = df_anagram_filtered.loc[(df_anagram['questions'].str.contains("AALRYS", case=False))]
df7 = df_anagram_filtered.loc[(df_anagram['questions'].str.contains("AYKAWLJ", case=False))]
df8 = df_anagram_filtered.loc[(df_anagram['questions'].str.contains("NCRBOA", case=False))]
df9 = df_anagram_filtered.loc[(df_anagram['questions'].str.contains("MARNOD", case=False))]
df10 = df_anagram_filtered.loc[(df_anagram['questions'].str.contains("EVANG", case=False))]

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pandas as pd

fig = plt.figure(figsize=(12, 6))
gs = gridspec.GridSpec(2, 6)

for i in range(0, 5):
    if i < 3:
        ax = plt.subplot(gs[0, 2 * i:2 * i + 2])
    else:
        ax = plt.subplot(gs[1, 2 * i - 11:2 * i + 2 - 11])
    
    if i == 0:
        max_len = max(df6['close'].str.len())
        for j, row in df6.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends in the plot
            plt.plot(x2, row['close'], '-o')
        plt.title(df6['questions'].iloc[0][20:30]+'... \n'+' aha ='+str(round(df6['aha'].mean(),1))
                 +' diff ='+str(round(df6['difficulty'].mean(),1))+'\n rt ='+str(round(df6['rts'].mean(),1))
                 +' conf ='+str(round(df6['confidence'].mean(),1)))
    elif i == 1:
        max_len = max(df7['close'].str.len())
        for j, row in df7.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends in the plot
            plt.plot(x2, row['close'], '-o')
        plt.title(df7['questions'].iloc[0][20:30]+'...'+'\n aha ='+str(round(df7['aha'].mean(),1))
                 +' diff ='+str(round(df7['difficulty'].mean(),1))+'\n rt ='+str(round(df7['rts'].mean(),1))
                 +' conf ='+str(round(df7['confidence'].mean(),1)))
    elif i == 2:
        max_len = max(df8['close'].str.len())
        for j, row in df8.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends in the plot
            plt.plot(x2, row['close'], '-o')
        plt.title(df8['questions'].iloc[0][20:30]+'...'+'\n aha ='+str(round(df8['aha'].mean(),1))
                 +' diff ='+str(round(df3['difficulty'].mean(),1))+'\n rt ='+str(round(df8['rts'].mean(),1))
                 +' conf ='+str(round(df8['confidence'].mean(),1)))
    elif i == 3:
        max_len = max(df9['close'].str.len())
        for j, row in df9.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends in the plot
            plt.plot(x2, row['close'], '-o')
        plt.title(df9['questions'].iloc[0][20:30]+'...'+'\n aha ='+str(round(df9['aha'].mean(),1))
                 +' diff ='+str(round(df9['difficulty'].mean(),1))+'\n rt ='+str(round(df9['rts'].mean(),1))
                 +' conf ='+str(round(df9['confidence'].mean(),1)))
    elif i == 4:
        max_len = max(df10['close'].str.len())
        for j, row in df10.iterrows():
            x = list(range(0, len(row['close'])))
            x2 = [(max_len-len(x))+i for i in x] #align the ends in the plot
            plt.plot(x2, row['close'], '-o')
        plt.title(df10['questions'].iloc[0][20:30]+'...'+'\n aha ='+str(round(df10['aha'].mean(),1))
                 +' diff ='+str(round(df10['difficulty'].mean(),1))+'\n rt ='+str(round(df10['rts'].mean(),1))
                 +' conf ='+str(round(df10['confidence'].mean(),1)))
            
plt.tight_layout()
plt.show()

# %%
print(df_anagram_filtered['aha'].mean(), df_non_insight_filtered['aha'].mean())
print(df_anagram_filtered['confidence'].mean(), df_non_insight_filtered['confidence'].mean())
print(df_anagram_filtered['difficulty'].mean(), df_non_insight_filtered['difficulty'].mean())
# Out:
# 5.324324324324325 2.8793103448275863
# 6.621621621621622 5.4655172413793105
# 3.7837837837837838 3.810344827586207

# %%
df_non_insight_filtered
# Out:
#                                                                                                                                                                                                  questions                                                                                                                                                                                                 answers           solutions       rts  confidence  difficulty  aha                                                                                           close
# 0   A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                                                   [{"Q0":""}, {"Q0":""}, {"Q0":"done"}]       {"Q0":"west"}   22.8621           6           4    4                                                                                    [41, 78, 94]
# 1   The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                            [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"pear"}   72.8917           6           3    2                                                                       [0, 3, 0, 2, 0, 2, 0, 99]
# 4   Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                 [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Friday"}   82.4096           6           2    2                                                            [6, 14, 22, 46, 55, 83, 90, 93, 100]
# 5   Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Done"}]    {"Q0":"Friday "}   62.3180           6           3    5                                                                         [1, 0, 0, 0, 7, 0, 100]
# 6                         Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                            [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"41"}   72.5610           6           5    2                                                               [22, 27, 46, 59, 70, 68, 97, 100]
# 9                         Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]         {"Q0":"41"}   52.4954           7           5    4                                                                         [0, 8, 3, 76, 100, 100]
# 10  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"do"}, {"Q0":"DONE"}]      {"Q0":"south"}   43.3005           7           1    2                                                                          [28, 33, 56, 100, 100]
# 11                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                            [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"41"}   73.6422           7           1    1                                                                [21, 27, 36, 38, 41, 38, 33, 83]
# 12  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Friday"}   53.0148           7           2    1                                                                           [0, 0, 0, 1, 45, 100]
# 15                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"41"}   41.8737           5           3    3                                                                           [21, 18, 70, 85, 100]
# 18  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                      [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Friday"}   92.3321           6           5    1                                                        [0, 4, 18, 52, 54, 54, 79, 83, 100, 100]
# 19                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                               [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"41"}, {"Q0":"DONE"}]         {"Q0":"41"}   82.7670           6           2    5                                                               [0, 10, 13, 8, 0, 3, 41, 72, 100]
# 20                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                               [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"41"}, {"Q0":"DONE"}]         {"Q0":"41"}   82.4969           7           5    5                                                         [52, 53, 36, 53, 71, 64, 100, 100, 100]
# 22                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]        {"Q0":"$41"}   33.3534           5           3    2                                                                                 [4, 16, 81, 97]
# 23  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"...       {"Q0":"Pear"}  284.3153           5           6    6  [3, 5, 9, 4, 9, 10, 4, 7, 3, 3, 11, 5, 3, 2, 3, 1, 5, 3, 3, 3, 2, 0, 10, 8, 6, 51, 57, 93, 81]
# 28  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                                    [{"Q0":""}, {"Q0":""}, {"Q0":"LEFT"}, {"Q0":"DONE"}]       {"Q0":"Left"}   32.2546           6           5    3                                                                                 [0, 74, 97, 97]
# 29                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                          [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]   {"Q0":"Thursday"}  133.1652           6           6    4                                            [0, 12, 7, 10, 5, 9, 17, 15, 11, 26, 51, 61, 86, 93]
# 31  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                     [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"friday"}, {"Q0":"friday"}, {"Q0":""}, {"Q0":"done"}]     {"Q0":"friday"}   83.4302           5           6    3                                                              [4, 9, 10, 19, 45, 82, 70, 57, 70]
# 32  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                 [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Friday"}   84.9573           7           2    3                                                              [0, 0, 0, 6, 19, 14, 52, 100, 100]
# 34  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                                                         [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"pear"}, {"Q0":"DONE"}]       {"Q0":"pear"}   43.8305           6           2    2                                                                              [9, 8, 7, 100, 98]
# 36  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                                                   [{"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"monday"}   21.5941           6           6    6                                                                                  [14, 100, 100]
# 38  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DO"}, {"Q0":"DONE"}]      {"Q0":"North"}   41.8217           5           4    2                                                                            [18, 11, 51, 95, 94]
# 40  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]       {"Q0":"pear"}   51.9463           6           4    3                                                                        [10, 27, 38, 46, 47, 89]
# 42  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]     {"Q0":"Friday"}   53.5223           6           2    4                                                                           [0, 0, 0, 34, 75, 92]
# 43  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]      {"Q0":"South"}   52.7068           5           4    3                                                                           [2, 2, 0, 44, 93, 91]
# 44  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"friday"}   33.0861           7           4    5                                                                                 [0, 0, 51, 100]
# 48                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DO"}, {"Q0":"DONE"}]   {"Q0":"Thursday"}   43.7199           7           3    1                                                                            [12, 6, 16, 97, 100]
# 50                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]   {"Q0":"Thursday"}   38.7898           5           1    1                                                                                 [0, 67, 98, 97]
# 51                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]         {"Q0":"41"}   44.4187           5           5    1                                                                               [0, 0, 0, 0, 100]
# 52  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"pear"}  103.1800           5           4    4                                                          [0, 0, 0, 1, 0, 2, 16, 14, 47, 87, 88]
# 53  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]       {"Q0":"WEST"}   55.1663           6           3    5                                                                        [21, 23, 21, 24, 91, 17]
# 54  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Friday"}   63.5759           6           4    5                                                                       [0, 0, 0, 0, 0, 100, 100]
# 56  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"friday"}   42.7900           6           2    4                                                                            [15, 51, 64, 90, 98]
# 57  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]      {"Q0":"South"}   53.0889           5           7    1                                                                          [3, 2, 0, 36, 73, 100]
# 59                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"34"}   62.0235           5           5    4                                                                     [0, 20, 23, 17, 18, 78, 93]
# 60                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                           [{"Q0":""}, {"Q0":"Thursday"}, {"Q0":"DONE"}]   {"Q0":"Thursday"}   21.6030           5           5    5                                                                                    [72, 61, 74]
# 61  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                 [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Done"}]      {"Q0":"South"}   83.2751           6           5    2                                                             [21, 35, 23, 7, 30, 57, 67, 83, 91]
# 62                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]        {"Q0":"$48"}   64.9590           6           4    2                                                                    [0, 14, 39, 45, 58, 95, 100]
# 63  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]      {"Q0":"north"}   32.4736           5           3    2                                                                                [0, 27, 54, 100]
# 66                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Done"}]     {"Q0":"Friday"}   33.2767           5           4    4                                                                                 [2, 11, 53, 98]
# 67                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                                              [{"Q0":""}, {"Q0":"Done"}]   {"Q0":"Thursday"}   13.3510           7           2    1                                                                                       [54, 100]
# 68  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                           [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Friday"}  102.8907           6           3    4                                                          [2, 2, 2, 4, 6, 3, 5, 37, 31, 84, 100]
# 71  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"Done"}]      {"Q0":"North"}   42.3268           5           3    1                                                                             [3, 6, 27, 91, 100]
# 73                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]  {"Q0":"Wednesday"}   32.1275           6           4    6                                                                                [14, 45, 61, 92]
# 74  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Friday"}   35.1329           5           4    2                                                                                  [0, 0, 54, 95]
# 75  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]       {"Q0":"rear"}   52.1647           6           1    1                                                                         [0, 0, 9, 48, 100, 100]
# 76  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]      {"Q0":"South"}   43.2543           6           5    1                                                                            [2, 39, 18, 68, 100]
# 77                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                        [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]    {"Q0":"Tuesday"}   33.4972           5           4    4                                                                               [14, 16, 98, 100]
# 79                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                                   [{"Q0":""}, {"Q0":""}, {"Q0":"done"}]  {"Q0":"Wednesday"}   23.8459           6           2    3                                                                                    [23, 86, 78]
# 81                                                                                                                          What day follows the day before yesterday if two days from now will be Sunday?                                                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":"D"}, {"Q0":"done"}]   {"Q0":"Thursday"}   34.9529           6           3    2                                                                                 [20, 5, 99, 99]
# 85                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"41"}   52.7355           5           4    3                                                                           [2, 7, 6, 38, 76, 57]
# 89                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                      [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"41"}   94.1210           5           4    3                                                              [0, 1, 10, 7, 7, 8, 8, 16, 56, 90]
# 91                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]         {"Q0":"64"}   62.9033           5           2    1                                                                       [0, 0, 0, 0, 0, 100, 100]
# 92  Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; th...                                                                                                                                                                   [{"Q0":""}, {"Q0":""}, {"Q0":"DONE"}]     {"Q0":"Monday"}   22.3989           5           5    6                                                                                      [0, 6, 81]
# 95  The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not ...                                                                                                                                             [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]       {"Q0":"pear"}   42.0560           7           6    5                                                                          [16, 23, 51, 100, 100]
# 97  A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now fa...                                                                                                                       [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"done"}]       {"Q0":"east"}   67.8208           5           5    3                                                                      [0, 5, 19, 47, 66, 98, 98]
# 98                        Ben spent $42 for shoes. This was $14 less than what he spent for a shirt and twice more expensive than the tie. The tie was $20 cheaper than the jeans. How much was the jeans?                                                  [{"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":""}, {"Q0":"41"}, {"Q0":"4"}, {"Q0":"DONE"}]         {"Q0":"41"}  122.7040           7           3    6                                           [10, 15, 11, 13, 22, 13, 8, 9, 20, 75, 100, 100, 100]
