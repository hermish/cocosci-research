# %%
# Analytical Tools
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# General Utilities
import math
import json
import pprint
import itertools
import importlib

# Some settings
from IPython.display import Markdown, display
log = pprint.pprint
space = lambda: print()
printmd = lambda text: display(Markdown(text))
# %matplotlib inline

def set_pandas_display_options() -> None:
    """Set pandas display options."""
    display = pd.options.display

    display.max_columns = 1000
    display.max_rows = 1000
    display.max_colwidth = 199
    display.width = 1000
    # display.precision = 2  # set as needed

set_pandas_display_options()

# %%
non_insight = ['Mary won\'t eat fish or spinach, Sally won\'t eat fish or green beans, Steve won\'t eat shrimp or potatoes, Alice won\'t eat beef or tomatoes, and Jim won\'t eat fish or tomatoes. If you are willing to host all these people for a dinner party, which items from the following list can you serve: green beans, creamed codfish, roast beef, roast chicken, celery, and lettuce?','Three spies, suspected as double agents, speak as follows when questioned: Albert: "Bertie is a mole." Bertie: "Cedric is a mole." Cedric: "Bertie is lying." Assuming that moles lie, other agents tell the truth, and there is just one mole among the three, who is the mole? Albert, Bertie, or Cedric?',
	'What day follows the day before yesterday if two days from now will be Sunday?',
	'A group of soldiers were standing facing west. Their sergeant shouted at them: Right turn! U-turn! Left turn! U-turn! Right turn! U-turn! Left turn! Right turn! In which direction are they now facing?',
	'There are three playing cards lying face up, side by side. A five is just to the right of a two. A five is just to the left of a two. A spade is just to the left of a club, and a spade is just to the right of a spade. What are the three cards?',
	'The following verse spells out a word. I am a food for you and me. My first letter is in pat but not in tar. My second letter is in stream but not in smart. My third letter is in giraffe but not in fridge. My fourth letter is in treat but not in absent. What is the word that this verse described?',
	'Next week I am going to have lunch with my friend, visit the new art gallery, go to the Social Security office, and have my teeth checked at the dentist. My friend cannot meet me on Wednesday; the Social Security office is closed weekends; the dentist has office hours only on Tuesday, Friday, and Saturday; the art gallery is closed Tuesday, Thursday, and weekends. On what single day can I do everything I have planned?',
	'Paula is trying to get in shape. She wants to do this by climbing stairs. She starts on the fourth floor, climbs up five stories, down seven, up six, down three, and up four again. What floor is she on now?',
	'Ben spent $42 for shoes. This was $14 less than twice what he spent for a shirt. The shirt was $20 less expensive than the jeans. How much was the jeans?',
	'Three people play a game in which one person loses and two people win each round. The one who loses must double the amount of money that each of the other two players has at that time. The three players agree to play three games. At the end of the three games, each player has lost one game and each person has $8. What was the original stake of each player?',
	'Solve for a and b: 3a+6b = 5, and 2a-b=1. In the answer box, provide the values of a and b.',
	'Solve for x, y, and z: x+2y-z = 13, 2x+y+z = 8, and 3x-y-2z = 1. In the answer box, provide the values of x, y, and z.',
	 'Given the numbers 100, 3, 15, 11, and 14, how can you obtain exactly 101. You can use multiplication, division, addition, and subtraction but the only constraint is that you have to use all of these numbers.',
	 'Andrew is half the age of Brian, Brian is three times older than Charles and the sum of their ages is 44 years. How old is Charles?',
	 'Calculate the age of Rob given that Rob\'s father is 45 and he is 15 years older than twice Rob\'s age.'];

insight = ['Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?',
'A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?',
'A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?',
'A man is reading a book when the lights go off but even although the room is pitch dark the man goes on reading. How?',
'Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?',
'A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: \'This child is my son!\' Who is the doctor?',
'Anthony and Cleopatra are lying dead on the floor in an Egyptian villa. Nearby is a broken bowl. There are no marks on their bodies and they were not poisoned. Not a person was in the villa when they died. How did they die?',
'Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?',
'A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How could this be?',
'Bob\'s driver\'s license was recently revoked, following a string of severe traffic violations. Just a few days later, a cop spotted the unlicensed Bob yet again, entering a one-way street against the direction of the traffic. This was the same cop who had cited Bob before. However, the cop did not stop him, and just gave him a smile. Why?',
'Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?',
'A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that haven\'t eaten in 3 years. Which room is safest for him?',
'Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?',
'Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through security with a wheelbarrow full of scrap lumber, discarded electrical wires, and chunks of concrete. The security guards checked the contents daily, but could find nothing of value. What was Shady stealing?',
'Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?'];
 
anagram = ['Solve this anagram: AXPLINE', 
						'Solve this anagram: LUBMEJD', 
						'Solve this anagram: AALRYS',
						'Solve this anagram: EURADBL',
						'Solve this anagram: NAYUGHT',
						'Solve this anagram: HSOADW',
						'Solve this anagram: DONRO',
						'Solve this anagram: MARNOD',
						'Solve this anagram: HAKMOCM',
						'Solve this anagram: RDFUNE',
						'Solve this anagram: EVANG',
						'Solve this anagram: SAOSI',
						'Solve this anagram: IEGWHT',
						'Solve this anagram: AYKAWLJ',
						'Solve this anagram: NCRBOA']

solutions2 = 'explain|jumbled|salary|durable|naughty|shadow|donor|random|hammock|vegan|refund|oasis|weight|jaywalk|carbon'

# %%
with open('pilot1.json') as json_file:
    data = json.load(json_file)

# %%
questions_non_insight = []
answers_non_insight = []
confidence_non_insight = []
difficulty_non_insight = []
aha_non_insight = []

questions_insight = []
answers_insight = []
confidence_insight = []
difficulty_insight = []
aha_insight = []

questions_anagram = []
answers_anagram = []
confidence_anagram = []
difficulty_anagram = []
aha_anagram = []

for i in range(198): #go thru the subjects
    if len(data[i]['data']) > 3: #only look at subjects that finished the task (and not just started without finishing)
        if int(data[i]['data'][3]['responses'][7]) == 6: #passed attention/quiz check, hooray!
            
            for j in range(6): #go through the 6 problems shown to people
                question = data[i]['data'][0]['problems_seen'][j] #store the question seen by the participant
                answer = data[i]['data'][j*3+5]['responses'] #store people's answers to the questions here
                response = data[i]['data'][j*3+6]['responses'] #store people's responses to the questions here
                
                if question in non_insight:   
                    questions_non_insight.append(question)
                    answers_non_insight.append(answer)
                    confidence_non_insight.append(int(response[6])+1)
                    difficulty_non_insight.append(int(response[13])+1)
                    aha_non_insight.append(int(response[20])+1)
                    
                elif question in insight:
                    questions_insight.append(question)
                    answers_insight.append(answer)
                    confidence_insight.append(int(response[6])+1)
                    difficulty_insight.append(int(response[13])+1)
                    aha_insight.append(int(response[20])+1)
                
                elif question in anagram:
                    questions_anagram.append(question)
                    answers_anagram.append(answer)
                    confidence_anagram.append(int(response[6])+1)
                    difficulty_anagram.append(int(response[13])+1)
                    aha_anagram.append(int(response[20])+1)
        else:     
            print('bad subject!')
# Out:
# bad subject!
# bad subject!
# bad subject!
# bad subject!

# %% [markdown]
# Convert data into df

# %%
d = {'questions':questions_non_insight,
     'answers':answers_non_insight, 
     'confidence': confidence_non_insight, 
     'difficulty': difficulty_non_insight, 
     'aha': aha_non_insight}

d2 = {'questions':questions_insight,
     'answers':answers_insight, 
     'confidence': confidence_insight, 
     'difficulty': difficulty_insight, 
     'aha': aha_insight}

d3 = {'questions':questions_anagram,
     'answers':answers_anagram, 
     'confidence': confidence_anagram, 
     'difficulty': difficulty_anagram, 
     'aha': aha_anagram}

df_non_insight = pd.DataFrame(d)
df_insight = pd.DataFrame(d2)
df_anagram = pd.DataFrame(d3)

#Analyze only those responses for which people's confidence is greater than 5
df_non_insight_filtered = df_non_insight.loc[(df_non_insight['confidence'] >= 5)]
df_insight_filtered = df_insight.loc[(df_insight['confidence'] >= 5)]
df_anagram_filtered = df_anagram.loc[(df_anagram['confidence'] >= 5)]

print(len(df_non_insight.index), len(df_non_insight_filtered.index))
print(len(df_insight.index), len(df_insight_filtered.index))
print(len(df_anagram.index), len(df_anagram_filtered.index))
# Out:
# 170 90
# 170 77
# 170 122

# %%
df_anagram_filtered = df_anagram.loc[(df_anagram['answers'].str.contains(solutions2, case = False)==True)]
df3 = df_anagram.groupby(['questions']).agg(['mean', 'count'])
df4 = df_anagram_filtered.groupby(['questions']).agg(['mean', 'count'])
print('% Solved')
print(df4['difficulty']['count']/df3['difficulty']['count'])
print('Counts')
print(df4['difficulty']['count'])
print('Mean difficulty')
print(df4['difficulty']['mean'])
# Out:
# % Solved
# questions
# Solve this anagram: AALRYS     0.800000
# Solve this anagram: AXPLINE    0.538462
# Solve this anagram: AYKAWLJ    0.545455
# Solve this anagram: DONRO      0.750000
# Solve this anagram: EURADBL    0.666667
# Solve this anagram: EVANG      0.444444
# Solve this anagram: HAKMOCM    0.866667
# Solve this anagram: HSOADW     0.818182
# Solve this anagram: IEGWHT     0.769231
# Solve this anagram: LUBMEJD    0.818182
# Solve this anagram: MARNOD     0.857143
# Solve this anagram: NAYUGHT    1.000000
# Solve this anagram: NCRBOA     0.555556
# Solve this anagram: RDFUNE     0.714286
# Solve this anagram: SAOSI      0.700000
# Name: count, dtype: float64
# Counts
# questions
# Solve this anagram: AALRYS      8
# Solve this anagram: AXPLINE     7
# Solve this anagram: AYKAWLJ     6
# Solve this anagram: DONRO       9
# Solve this anagram: EURADBL     6
# Solve this anagram: EVANG       8
# Solve this anagram: HAKMOCM    13
# Solve this anagram: HSOADW      9
# Solve this anagram: IEGWHT     10
# Solve this anagram: LUBMEJD     9
# Solve this anagram: MARNOD      6
# Solve this anagram: NAYUGHT     7
# Solve this anagram: NCRBOA      5
# Solve this anagram: RDFUNE     10
# Solve this anagram: SAOSI       7
# Name: count, dtype: int64
# Mean difficulty
# questions
# Solve this anagram: AALRYS     2.625000
# Solve this anagram: AXPLINE    2.285714
# Solve this anagram: AYKAWLJ    3.500000
# Solve this anagram: DONRO      1.666667
# Solve this anagram: EURADBL    2.333333
# Solve this anagram: EVANG      2.875000
# Solve this anagram: HAKMOCM    2.538462
# Solve this anagram: HSOADW     2.444444
# Solve this anagram: IEGWHT     1.400000
# Solve this anagram: LUBMEJD    3.000000
# Solve this anagram: MARNOD     3.833333
# Solve this anagram: NAYUGHT    2.571429
# Solve this anagram: NCRBOA     3.400000
# Solve this anagram: RDFUNE     1.100000
# Solve this anagram: SAOSI      3.428571
# Name: mean, dtype: float64

# %%
df1 = df_non_insight.groupby(['questions', 'answers'], as_index=False).agg(['mean', 'count'])
df2 = df_insight.groupby(['questions', 'answers']).agg(['mean', 'count'])
df3 = df_anagram.groupby(['questions', 'answers']).agg(['mean', 'count'])

# %%
df1 = df_non_insight_filtered.groupby(['questions'], as_index=False).agg(['mean', 'count'])
df2 = df_insight_filtered.groupby(['questions'], as_index=False).agg(['mean', 'count'])
df3 = df_anagram_filtered.groupby(['questions'], as_index=False).agg(['mean', 'count'])
df2
# Out:
#                                                                                                                                                                                                         confidence       difficulty             aha
#                                                                                                                                                                                                               mean count       mean count      mean count
# questions
# A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: 'This child is...   6.200000     5   2.800000     5  4.400000     5
# A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                         6.111111     9   2.777778     9  1.777778     9
# A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                            6.666667     3   2.000000     3  6.000000     3
# A man is reading a book when the lights go off but even although the room is pitch dark the man goes on reading. How?                                                                                     6.000000     5   2.800000     5  3.600000     5
# A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that haven...   6.666667     9   2.666667     9  3.777778     9
# A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How could...   6.500000     2   3.000000     2  6.500000     2
# Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?                                                                               6.000000     3   3.000000     3  4.333333     3
# Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                   6.333333     6   2.666667     6  5.333333     6
# Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                    6.200000    10   2.500000    10  2.600000    10
# Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                6.600000     5   1.400000     5  5.200000     5
# Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through ...   5.333333     6   2.833333     6  4.500000     6
# Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                        6.181818    11   2.000000    11  1.909091    11
# Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                         6.000000     3   2.000000     3  5.000000     3

# %%
df_insight
# Out:
#                                                                                                                                                                                                   questions                                                                                                                                                                                                 answers  confidence  difficulty  aha
# 0                                                                                                Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                                                                        {"Q0":"Women's basketball team"}           2           4    2
# 1    Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                          {"Q0":"Money"}           4           3    1
# 2    A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                   {"Q0":"I'm not sure what it's called, but were they perhaps attached to each other?"}           2           4    4
# 3                                                                                        Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                                                                                                            {"Q0":"The lake was frozen"}           6           2    3
# 4                                                                                     A man is reading a book when the lights go off but even although the room is pitch dark the man goes on reading. How?                                                                                                                                                  {"Q0":"He is blind and is reading a book in braille "}           2           5    6
# 5    Bob's driver's license was recently revoked, following a string of severe traffic violations. Just a few days later, a cop spotted the unlicensed Bob yet again, entering a one-way street against ...                                                                                                                                                                                           {"Q0":"Next"}           1           6    1
# 6                                                                                                   Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                                                                                                           {"Q0":"NEXT"}           1           7    1
# 7    A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: 'This child i...                                                                                                                                                                               {"Q0":"the boy's mother"}           7           2    3
# 8    Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                {"Q0":"the wheelbarrow"}           5           3    5
# 9    A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: 'This child i...                                                                                                                                                                                        {"Q0":"the mom"}           6           4    6
# 10                                                                                    A man is reading a book when the lights go off but even although the room is pitch dark the man goes on reading. How?                                                                                                                                           {"Q0":"The man is blind and the book is written in braille."}           7           2    2
# 11                                                                                       Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                                                                                                            {"Q0":"The lake is frozen."}           7           4    3
# 12                                                                                        Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                                                                                                                           {"Q0":"next"}           1           7    1
# 13   A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: 'This child i...                                                                                                                                                                                     {"Q0":"the mother"}           4           4    2
# 14   Bob's driver's license was recently revoked, following a string of severe traffic violations. Just a few days later, a cop spotted the unlicensed Bob yet again, entering a one-way street against ...                                                                                                     {"Q0":"figured he will get caught sooner or later and maybe he was busy with another traffic stop"}           3           6    2
# 15                                                                                               Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                    {"Q0":"the points were made before halftime and the other teams coach forfeited and thus the teams scored no points after the half"}           1           6    4
# 16                                                   Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                                          {"Q0":"He had protection on "}           1           4    1
# 17   A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: 'This child i...                                                                                                                                                                     {"Q0":"the child has two fathers "}           2           3    1
# 18   A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                                                                           {"Q0":"next"}           1           6    1
# 19                           A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                          {"Q0":"she has multiple personality disorder"}           3           5    5
# 20   Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                           {"Q0":"next"}           1           7    1
# 21                                                                                        Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                                                                                                         {"Q0":"They are playing chess"}           7           2    5
# 22   A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: 'This child i...                                                                                                                                                                                     {"Q0":"His mother"}           6           2    6
# 23                                                   Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                         {"Q0":"He was on the first rung of the ladder"}           6           2    6
# 24   Bob's driver's license was recently revoked, following a string of severe traffic violations. Just a few days later, a cop spotted the unlicensed Bob yet again, entering a one-way street against ...                                                                                                                                                                    {"Q0":"he was walking, not driving"}           4           4    1
# 25                                                                                       Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                                                                                                               {"Q0":"it was iced over"}           7           1    1
# 26                                        A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                                                                                                                                                                             {"Q0":"20"}           7           2    1
# 27                                                                                       Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                                                                                                                  {"Q0":"it was frozen"}           6           3    1
# 28                                                                              Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?                                                                                                                                                             {"Q0":"Alex and Casey are Bobbies parents"}           4           5    4
# 29   Anthony and Cleopatra are lying dead on the floor in an Egyptian villa. Nearby is a broken bowl. There are no marks on their bodies and they were not poisoned. Not a person was in the villa when ...                                                                                                                                                                                   {"Q0":"Heart attack"}           1           6    1
# 30                                                                                        Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                                                                                                          {"Q0":"because shes royalty?"}           1           6    1
# 31   Bob's driver's license was recently revoked, following a string of severe traffic violations. Just a few days later, a cop spotted the unlicensed Bob yet again, entering a one-way street against ...                                                                                                                                                          {"Q0":"because he knows that bob wont listen"}           3           5    2
# 32   Anthony and Cleopatra are lying dead on the floor in an Egyptian villa. Nearby is a broken bowl. There are no marks on their bodies and they were not poisoned. Not a person was in the villa when ...                                                                                                                                                                       {"Q0":"bowl fell on their heads"}           4           5    2
# 33   A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that have...                                                                                                                                                                                      {"Q0":"assassins"}           5           4    4
# 34   Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                {"Q0":"The wheelbarrow"}           5           4    1
# 35                                                                                       Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                                                                                                                    {"Q0":"Frozen lake"}           7           1    1
# 36                                                   Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                                       {"Q0":"He was on the first rung"}           6           3    4
# 37                                        A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                                                                                                                                                                    {"Q0":"He made $20"}           5           4    2
# 38                                        A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                                                                                                                                                                             {"Q0":"20"}           6           3    1
# 39                                                   Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                      {"Q0":"He fell from a very short distance, possible only one step on the ladder."}           7           1    1
# 40                                                                                        Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                             {"Q0":"Maybe they didn't think it was their place to say anything because the fighting was between royals"}           2           4    1
# 41                           A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                      {"Q0":"Maybe he married them prior to polygamy becoming unlawful"}           1           4    1
# 42   A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                                                                    {"Q0":"Son had DID"}           1           5    1
# 43                                                                                               Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                                                                                   {"Q0":"Women’s team"}           5           3    5
# 44                                                   Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                {"Q0":"he landed on something that reinforced the fall"}           2           5    2
# 45                                                                                                  Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                                                        {"Q0":"he knows someone on the inside who is rigging the games"}           2           4    2
# 46   A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                            {"Q0":"it was day light savings and they went back an hour"}           1           6    1
# 47   A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that have...                                                                                                                                                                                      {"Q0":"the lions"}           6           2    2
# 48   A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                                                         {"Q0":"The woman is not human"}           1           7    1
# 49                                        A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                                                                                                                                                                    {"Q0":"He made $10"}           2           5    1
# 50                                                                                        Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                                                                                                         {"Q0":"It was a game of chess"}           6           2    5
# 51   Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                         {"Q0":"Time? "}           1           6    1
# 52   Anthony and Cleopatra are lying dead on the floor in an Egyptian villa. Nearby is a broken bowl. There are no marks on their bodies and they were not poisoned. Not a person was in the villa when ...                                                                                                                                                                                {"Q0":"Natural causes?"}           1           7    1
# 53                                                                                               Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                        {"Q0":"It's impossible to score 1 point in basketball unless it's a fowl shot."}           3           6    1
# 54                                                                                                  Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                                                                  {"Q0":"he tells you the score of past football games"}           6           3    6
# 55   A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                                                              {"Q0":"different fathers"}           1           5    5
# 56                                        A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                                                                                                                                                                             {"Q0":"20"}           6           3    2
# 57                                                                              Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?                                                                                                                                                                                           {"Q0":"next"}           1           7    1
# 58                                                   Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                             {"Q0":"he was at the bottom of the ladder"}           2           2    4
# 59   Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                {"Q0":"the wheelbarrow"}           5           2    6
# 60                                                                                               Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                                                                                   {"Q0":"women's team"}           7           1    6
# 61   A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                      {"Q0":"she's a midwife and helped two different women give birth"}           6           2    6
# 62                                                                                               Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                                                                 {"Q0":"it's a women's basketball team"}           7           1    5
# 63                                                                              Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?                                                                                                                                                                                 {"Q0":"they are older"}           7           3    4
# 64   Bob's driver's license was recently revoked, following a string of severe traffic violations. Just a few days later, a cop spotted the unlicensed Bob yet again, entering a one-way street against ...                                                                                                                                                                   {"Q0":"He knows what is coming next"}           1           5    1
# 65                           A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                                    {"Q0":"He had common law marriages"}           1           4    1
# 66   Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                {"Q0":"the wheelbarrow"}           6           3    7
# 67                           A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                                                               {"Q0":""}           1           6    1
# 68                                                                                               Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                                                                {"Q0":"It's a women's basketball team."}           7           1    5
# 69                                                   Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                                     {"Q0":"He was on the bottom rung."}           7           1    3
# 70   A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that have...                                                                                                                                              {"Q0":"Lions that have not eaten in three years are dead"}           7           1    4
# 71                                                                                               Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                                                                   {"Q0":"Not one Man, but many scored"}           1           4    2
# 72                                                                              Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?                                                                                                                                                           {"Q0":"Alex and Casey are Bobbie's parents."}           5           4    5
# 73                                                                                    A man is reading a book when the lights go off but even although the room is pitch dark the man goes on reading. How?                                                                                                                                                          {"Q0":"The man is blind and reading Braille."}           4           3    3
# 74                                                                                    A man is reading a book when the lights go off but even although the room is pitch dark the man goes on reading. How?                                                                                                                                                                               {"Q0":"the man is blind"}           5           4    5
# 75                                                                                                  Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                                                                                                           {"Q0":"NEXT"}           1           6    1
# 76   A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                                                                  {"Q0":"superfetation"}           2           6    5
# 77                                                                                       Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                                                                                                            {"Q0":"the lake was frozen"}           3           2    3
# 78                                        A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                                                                                                                                                                            {"Q0":"$10"}           6           6    2
# 79                                                                                    A man is reading a book when the lights go off but even although the room is pitch dark the man goes on reading. How?                                                                                                                                                                {"Q0":"He is listening to an audiobook"}           2           3    2
# 80                                                                                               Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                                                                                {"Q0":"Technicalities "}           1           6    1
# 81   A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that have...                                                                                                                                                                                              {"Q0":"2"}           1           4    4
# 82                                                                                               Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                                                                                           {"Q0":"NEXT"}           1           7    1
# 83                                                                                                  Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                                                                     {"Q0":"The score for every game at the start is 0"}           4           1    3
# 84                                                                                    A man is reading a book when the lights go off but even although the room is pitch dark the man goes on reading. How?                                                                                                                                                          {"Q0":"He is blind and the book is in braile"}           7           3    6
# 85                           A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                         {"Q0":"the man is a pastor and he officiated their ceremonies"}           7           2    7
# 86   Anthony and Cleopatra are lying dead on the floor in an Egyptian villa. Nearby is a broken bowl. There are no marks on their bodies and they were not poisoned. Not a person was in the villa when ...                                                                                                                                                                                           {"Q0":"NEXT"}           1           5    1
# 87                                                                                                  Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                                                                                              {"Q0":"He says it is 0-0"}           7           3    5
# 88   A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that have...                                                                                                                                                                                      {"Q0":"the lions"}           7           1    1
# 89                                                                                    A man is reading a book when the lights go off but even although the room is pitch dark the man goes on reading. How?                                                                                                                                                         {"Q0":"he is blind and the book is in braille"}           5           3    3
# 90   Anthony and Cleopatra are lying dead on the floor in an Egyptian villa. Nearby is a broken bowl. There are no marks on their bodies and they were not poisoned. Not a person was in the villa when ...  {"Q0":"They didn't die in the villa, they were murdered outside the villa and their dead bodies were brought to the spot they're in inside the villa. \"not a person in the villa\" would have to i...           4           4    6
# 91   A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                             {"Q0":"They were a triplet with two sons and one daughter"}           7           4    7
# 92                                                                                       Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                                                                                                                            {"Q0":"Ice"}           6           1    1
# 93   Anthony and Cleopatra are lying dead on the floor in an Egyptian villa. Nearby is a broken bowl. There are no marks on their bodies and they were not poisoned. Not a person was in the villa when ...                                                                                                                                                                                  {"Q0":"They starved."}           2           3    2
# 94                           A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                                  {"Q0":"Not all were legal marriages."}           6           2    5
# 95                                        A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                                                                                                                                                              {"Q0":"He made $10 net. "}           5           3    2
# 96                                                   Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                       {"Q0":"He was only standing on the bottom rung."}           6           4    2
# 97                                                                                       Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                                                                                                           {"Q0":"The lake was frozen."}           7           2    2
# 98                           A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                                                           {"Q0":"Next"}           1           7    1
# 99   A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that have...                                                                                                                                                                                          {"Q0":"third"}           7           6    7
# 100  A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that have...                                                                                                                            {"Q0":"The 3rd because the lions are dead since they havent ate in 3 years"}           7           2    1
# 101                                       A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                                                                                                                                                                    {"Q0":"He made $20"}           7           1    1
# 102                                                                                       Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                                                                                                                           {"Q0":"NEXT"}           1           5    2
# 103  A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: 'This child i...                                                                                                                                                                          {"Q0":"The Great Grandfather"}           5           5    6
# 104  A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                                                                               {"Q0":""}           1           6    1
# 105                                                                             Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?                                                                                                                                                               {"Q0":"They're related through marriage"}           6           2    4
# 106                          A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                                                               {"Q0":""}           1           7    1
# 107  A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                                                                    {"Q0":" a mid wife"}           4           7    4
# 108  Anthony and Cleopatra are lying dead on the floor in an Egyptian villa. Nearby is a broken bowl. There are no marks on their bodies and they were not poisoned. Not a person was in the villa when ...                                                                                                                                                                                           {"Q0":"next"}           1           6    1
# ...
# 134  A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: 'This child i...                                                                                                                                                                             {"Q0":"The child's mother"}           7           1    1
# 135                                                                             Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?                                                                                                                                                      {"Q0":"They are only blood relatives of Bobbie. "}           2           4    1
# 136                                                                                      Someone walked for 20 minutes on the surface of a lake without sinking but without any form of flotation aid. How?                                                                                                                                                                                {"Q0":"lake was frozen"}           5           2    2
# 137  Anthony and Cleopatra are lying dead on the floor in an Egyptian villa. Nearby is a broken bowl. There are no marks on their bodies and they were not poisoned. Not a person was in the villa when ...                                                                                                                                                                                           {"Q0":"next"}           1           6    1
# 138  A man and his son are in a serious car accident. The father is killed and the son is rushed to the emergency room. Upon arrival, the attending doctor looks at the child and screams: 'This child i...                                                                                                                                                                                     {"Q0":"The father"}           4           3    2
# 139                                       A man bought a horse for $60 and sold it for $70. Then he bought it back for $80 and sold it for $90. How much did he make or lose in the horse trading business?                                                                                                                                                                                    {"Q0":"He lost 120"}           2           3    3
# 140                                                  Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                             {"Q0":"he was standing on the bottom rung"}           7           1    1
# 141                          A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                  {"Q0":"he is a minister - he officiated the weddings"}           7           2    6
# 142                                                                                                 Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                             {"Q0":"It played on the East Coast at an earlier time and you watched it on a tape delay?"}           4           6    1
# 143  Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                {"Q0":"The wheelbarrow"}           6           2    5
# 144  A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that have...  {"Q0":"If by \"safest\", you mean \"least likely to kill him\", he should choose the room of lions because no animal can survive for three years without eating, so he would be entering a room ful...           7           2    7
# 145                                                                                                 Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                      {"Q0":"OHHHH, *before it starts*, when there is no score. There's no score before a game starts."}           7           3    7
# 146  A murderer is condemned to death. He has to choose among three rooms. The first is full of raging fires, the second is full of assassins with loaded guns, and the third is full of lions that have...                                                                                                                                                                                              {"Q0":"2"}           4           2    6
# 147                                                                                       Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                                                                                                {"Q0":"They're watching a chess match."}           5           2    5
# 148  A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                                                                                                       {"Q0":"she was the doctor delivering the babies"}           3           6    4
# 149  Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                               {"Q0":"the wheelbarrow "}           5           3    3
# 150                          A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                                              {"Q0":"He is the priest?"}           2           6    1
# 151                                                                                       Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                                                                                 {"Q0":"The two sisters were part of the royal family?"}           1           7    1
# 152                                                                                              Our basketball team won 72-49, and yet not one man scored as much as a single point. How is that possible?                                                                                                                                                                          {"Q0":"The team is all women"}           7           1    5
# 153                                                                                                 Joe Fan has no psychic powers but he can tell you the score of any football game before it starts. How?                                                                                                                                                {"Q0":"Before the game starts, the score is always 0-0"}           5           3    6
# 154                                                                             Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?                                                                                                                                                                                           {"Q0":"NEXT"}           1           4    1
# 155                                                  Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                             {"Q0":"THE LADDER WAS FLAT ON THE GROUND."}           7           1    1
# 156  A woman gave natural birth to two sons who were born on the same hour of the same day of the same month of the same year. But they were not twins and she had no access to a time machine. How coul...                                                                     {"Q0":"2 different sperm meaning the woman had sex with 2 different men on the same day and conception happened with both sperms."}           4           4    3
# 157  Bob's driver's license was recently revoked, following a string of severe traffic violations. Just a few days later, a cop spotted the unlicensed Bob yet again, entering a one-way street against ...                                                                                                                                                       {"Q0":"Cop didn't know his license was revoked."}           3           4    1
# 158  Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                    {"Q0":"wheelbarrow"}           2           6    1
# 159                                                  Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                                      {"Q0":"mr. hardy is not a person"}           2           6    1
# 160                          A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                   {"Q0":"They are the only people living in this town"}           1           5    1
# 161  Sid Shady was working for a large construction company that was very concerned about employee theft. Someone tipped company security that Shady was the man to watch. Each night, he passed through...                                                                                                                                                                                     {"Q0":"Their time"}           1           5    1
# 162                                                  Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                 {"Q0":"It never said how high up on the ladder he was"}           4           1    1
# 163                          A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                                                           {"Q0":"next"}           1           6    1
# 164                          A man in a small town married 20 different women of the same town. All are still living and he never divorced. Polygamy is unlawful but he has broken no law. How can this be?                                                                                                                                                                                           {"Q0":"next"}           1           3    1
# 165                                                                                       Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                                                                                                            {"Q0":"it was a chess game"}           1           3    1
# 166  Bob's driver's license was recently revoked, following a string of severe traffic violations. Just a few days later, a cop spotted the unlicensed Bob yet again, entering a one-way street against ...                                                                                                                            {"Q0":"the cop knew Bob would get into a bigger violation in a few minutes"}           2           6    1
# 167                                                                             Alex and Casey are blood relatives of Bobbie. However, Alex and Casey are not blood relatives at all. How is this possible?                                                                                   {"Q0":"alex and casey are blood relatives of bobbie from two different sides of the family (mom's side, dad's side)"}           2           3    1
# 168                                                  Mr. Hardy slipped and fell off a sixty-foot ladder onto the concrete floor below. However, he did not injure himself in any way. How is this possible?                                                                                                                                                       {"Q0":"He was on the bottom step of the ladder."}           5           6    3
# 169                                                                                       Two sisters along with a large group of people watched as the queen attacked the king. No one said anything. Why?                                                                                                                                                                       {"Q0":"They were playing chess."}           4           5    6

# %%
df3
# Out:
#                             confidence       difficulty             aha
#                                   mean count       mean count      mean count
# questions
# Solve this anagram: AALRYS    6.875000     8   2.625000     8  5.125000     8
# Solve this anagram: AXPLINE   6.714286     7   2.285714     7  3.142857     7
# Solve this anagram: AYKAWLJ   6.000000     6   3.500000     6  4.333333     6
# Solve this anagram: DONRO     6.900000    10   1.800000    10  4.700000    10
# Solve this anagram: EURADBL   7.000000     6   2.333333     6  4.666667     6
# Solve this anagram: EVANG     6.625000     8   2.875000     8  3.875000     8
# Solve this anagram: HAKMOCM   6.846154    13   2.538462    13  5.076923    13
# Solve this anagram: HSOADW    6.555556     9   2.444444     9  3.888889     9
# Solve this anagram: IEGWHT    6.800000    10   1.400000    10  4.800000    10
# Solve this anagram: LUBMEJD   6.625000     8   3.000000     8  5.250000     8
# Solve this anagram: MARNOD    6.833333     6   3.833333     6  4.333333     6
# Solve this anagram: NAYUGHT   6.714286     7   2.571429     7  4.857143     7
# Solve this anagram: NCRBOA    6.500000     6   3.333333     6  4.333333     6
# Solve this anagram: RDFUNE    6.818182    11   1.090909    11  3.272727    11
# Solve this anagram: SAOSI     6.428571     7   3.428571     7  5.000000     7

# %%
np.corrcoef(df3['difficulty'], df3['aha'])
# Out:
# /Users/rachitdubey/miniconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/rachitdubey/miniconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /Users/rachitdubey/miniconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# array([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan]])

# %% [markdown]
# Analyze only those responses for which people's confidence is greater than 5

# %%
print(df1["aha"].mean(),df2["aha"].mean(), df3["aha"].mean())
print(df1["difficulty"].mean(),df2["difficulty"].mean(), df3["difficulty"].mean())
print(df1["confidence"].mean(),df2["confidence"].mean(), df3["confidence"].mean())
# Out:
# mean    2.737908
# dtype: float64 mean    4.225486
# dtype: float64 mean    4.44368
# dtype: float64
# mean    2.811825
# dtype: float64 mean    2.495726
# dtype: float64 mean    2.603969
# dtype: float64
# mean    6.11589
# dtype: float64 mean    6.214841
# dtype: float64 mean    6.682358
# dtype: float64

# %%
print(df_non_insight["aha"].mean(),df_insight["aha"].mean(), df_anagram["aha"].mean())
print(df_non_insight["difficulty"].mean(),df_insight["difficulty"].mean(), df_anagram["difficulty"].mean())
print(df_non_insight["confidence"].mean(),df_insight["confidence"].mean(), df_anagram["confidence"].mean())
# Out:
# 2.1294117647058823 2.6882352941176473 3.5647058823529414
# 3.976470588235294 3.8529411764705883 3.4529411764705884
# 4.235294117647059 3.9176470588235293 5.170588235294118

# %%
print(df_non_insight_filtered["aha"].mean(),df_insight_filtered["aha"].mean(), df_anagram_filtered["aha"].mean())
print(df_non_insight_filtered["difficulty"].mean(),df_insight_filtered["difficulty"].mean(), df_anagram_filtered["difficulty"].mean())
print(df_non_insight_filtered["confidence"].mean(),df_insight_filtered["confidence"].mean(), df_anagram_filtered["confidence"].mean())
# Out:
# 2.7777777777777777 3.6493506493506493 4.425
# 2.6333333333333333 2.4805194805194803 2.4916666666666667
# 6.177777777777778 6.207792207792208 6.683333333333334

# %% [markdown]
# Plot distribution of curiosity ratings below
